# %% [markdown]
# <a href="https://colab.research.google.com/github/yihaozhong/479_data_management/blob/main/parse_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extracting Data from a CSV file

# %% [markdown]
# ### Challenges
#
# 1. What if the delimiter (,) is part of actual data?
# 2. Does it include the header?
# 3. Are there missing values?
# 4. What is the encoding (hopefully  utf-8)?
# 5. What are the actual types of data (are they meant to be strings? floats? etc.)

# %% [markdown]
# ### Short Example

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# assuming csv was downloaded (or uploaded to Colab or Google Drive)

with open('/content/drive/MyDrive/starbucks_drinkMenu_expanded.csv', 'r') as f:
    # use next to skip header (but maybe you want to do something with this header???)
    next(f)
    count = 0
    # loop over a file, line-by-line
    for line in f:
        # break up line using comma
        line_parts = line.split(',')
        # select only drinks that have calories over 400
        # (make sure to attempt int conversion; should prob wrap in try except, no?)
        if int(line_parts[3]) > 400:
            print(line_parts[1:4])
# Out:
# ['White Chocolate Mocha (Without Whipped Cream)', 'Venti Nonfat Milk', '450']
# ['White Chocolate Mocha (Without Whipped Cream)', '2% Milk', '510']
# ['White Chocolate Mocha (Without Whipped Cream)', 'Soymilk', '460']
# ['Tazo® Green Tea Latte', '2% Milk', '450']
# ['Java Chip (Without Whipped Cream)', 'Venti Nonfat Milk', '420']
# ['Java Chip (Without Whipped Cream)', 'Whole Milk', '460']
# ['Java Chip (Without Whipped Cream)', 'Soymilk', '430']

# %%
import pandas as pd
starbucks=pd.read_csv('/content/drive/MyDrive/starbucks_drinkMenu_expanded.csv')
starbucks[starbucks['Calories']>400][['Beverage','Beverage_prep','Calories']]
# Out:
#                                           Beverage      Beverage_prep  Calories
# 83   White Chocolate Mocha (Without Whipped Cream)  Venti Nonfat Milk       450
# 84   White Chocolate Mocha (Without Whipped Cream)            2% Milk       510
# 85   White Chocolate Mocha (Without Whipped Cream)            Soymilk       460
# 128                          Tazo® Green Tea Latte            2% Milk       450
# 214              Java Chip (Without Whipped Cream)  Venti Nonfat Milk       420
# 215              Java Chip (Without Whipped Cream)         Whole Milk       460
# 216              Java Chip (Without Whipped Cream)            Soymilk       430

# %%
starbucks.head(10)
# Out:
#          Beverage_category       Beverage  ... Iron (% DV)   Caffeine (mg)
# 0                   Coffee  Brewed Coffee  ...           0%            175
# 1                   Coffee  Brewed Coffee  ...           0%            260
# 2                   Coffee  Brewed Coffee  ...           0%            330
# 3                   Coffee  Brewed Coffee  ...           0%            410
# 4  Classic Espresso Drinks    Caffè Latte  ...           0%             75
# 5  Classic Espresso Drinks    Caffè Latte  ...           0%             75
# 6  Classic Espresso Drinks    Caffè Latte  ...           8%             75
# 7  Classic Espresso Drinks    Caffè Latte  ...           0%             75
# 8  Classic Espresso Drinks    Caffè Latte  ...           0%             75
# 9  Classic Espresso Drinks    Caffè Latte  ...          15%             75
#
# [10 rows x 18 columns]
